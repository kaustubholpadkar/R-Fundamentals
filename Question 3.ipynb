# %% [markdown]
# ## Asignment 1

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### Start R using the shortcut created earlier. Download the file.
# #### http://stats.ma.ic.ac.uk/das01/public_html/RCourse/hills.txt
# #### Read the file, assigning the result to the object hills. Examine the object. Note column and row names. Construct a scatterplot matrix for dist vs. time. Make the columns of the hills object available by name. Compute a linear regression of time against distance.

# %%
hills <- read.table("hills.txt", header = TRUE)

# %%
head(hills)
# Out:
#   Race        Distance Climb Time
# 1 Greenmantle 2.5       650  16.083
# 2 Carnethy    6.0      2500  48.350
# 3 CraigDunain 6.0       900  33.650
# 4 BenRha      7.5       800  45.600
# 5 BenLomond   8.0      3070  62.267
# 6 Goatfell    8.0      2866  73.217

# %%
attach(hills)

# %%
plot(Distance, Time)
# Out:
# plot without title

# %%
lm(Time~Distance)
# Out:
# Call:
# lm(formula = Time ~ Distance)
#
# Coefficients:
# (Intercept)     Distance
#      -4.841        8.330

# %%
# png(file = "linearregression.png")

# Plot the chart.
plot(Distance,Time,col = "blue",main = "Time vs Distance",
abline(lm(Time~Distance)),xlab = "Distance",ylab = "Time")

# Save the file.
# dev.off()
# Out:
# Plot with title “Time vs Distance”
